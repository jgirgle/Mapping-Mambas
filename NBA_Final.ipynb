# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/girgs/Desktop/mapping_mambas'

# %%
nba_finals_db = pd.read_csv("csv_files/raw_file/NBA Finals and MVP.csv")

# %%
nba_finals_db
# Out:
#     Year       Western Champion     Eastern Champion Result  \
# 0   1950     Minneapolis Lakers   Syracuse Nationals    4–2
# 1   1951       Rochester Royals      New York Knicks    4–3
# 2   1952     Minneapolis Lakers      New York Knicks    4–3
# 3   1953     Minneapolis Lakers      New York Knicks    4–1
# 4   1954     Minneapolis Lakers   Syracuse Nationals    4–3
# ..   ...                    ...                  ...    ...
# 66  2016  Golden State Warriors  Cleveland Cavaliers    4–3
# 67  2017  Golden State Warriors  Cleveland Cavaliers    4-2
# 68  2018  Golden State Warriors  Cleveland Cavaliers    4-0
# 69  2019  Golden State Warriors      Toronto Raptors    4-2
# 70  2020     Los Angeles Lakers           Miami Heat    4-1
#
#              NBA Champion      NBA Vice-Champion  Final Sweep ?  \
# 0      Minneapolis Lakers     Syracuse Nationals          False
# 1        Rochester Royals        New York Knicks          False
# ...

# %%
champions_by_year = nba_finals_db[['Year', 'NBA Champion']]
champions_by_year
# Out:
#     Year           NBA Champion
# 0   1950     Minneapolis Lakers
# 1   1951       Rochester Royals
# 2   1952     Minneapolis Lakers
# 3   1953     Minneapolis Lakers
# 4   1954     Minneapolis Lakers
# ..   ...                    ...
# 66  2016    Cleveland Cavaliers
# 67  2017  Golden State Warriors
# 68  2018  Golden State Warriors
# 69  2019        Toronto Raptors
# 70  2020     Los Angeles Lakers
#
# [71 rows x 2 columns]

# %%
runner_up_by_year = nba_finals_db[['Year', 'NBA Vice-Champion']]
runner_up_by_year
# Out:
#     Year      NBA Vice-Champion
# 0   1950     Syracuse Nationals
# 1   1951        New York Knicks
# 2   1952        New York Knicks
# 3   1953        New York Knicks
# 4   1954     Syracuse Nationals
# ..   ...                    ...
# 66  2016  Golden State Warriors
# 67  2017    Cleveland Cavaliers
# 68  2018    Cleveland Cavaliers
# 69  2019  Golden State Warriors
# 70  2020             Miami Heat
#
# [71 rows x 2 columns]

# %%
mvp_by_year = nba_finals_db[['Year', 'MVP Name']]
mvp_by_year
# Out:
#     Year          MVP Name
# 0   1950               NaN
# 1   1951               NaN
# 2   1952               NaN
# 3   1953               NaN
# 4   1954               NaN
# ..   ...               ...
# 66  2016          S. Curry
# 67  2017      R. Westbrook
# 68  2018         J. Harden
# 69  2019  G. Antetokounmpo
# 70  2020  G. Antetokounmpo
#
# [71 rows x 2 columns]

# %%
finals_appearance = nba_finals_db[['Year', 'Western Champion', 'Eastern Champion']]
finals_appearance
# Out:
#     Year       Western Champion     Eastern Champion
# 0   1950     Minneapolis Lakers   Syracuse Nationals
# 1   1951       Rochester Royals      New York Knicks
# 2   1952     Minneapolis Lakers      New York Knicks
# 3   1953     Minneapolis Lakers      New York Knicks
# 4   1954     Minneapolis Lakers   Syracuse Nationals
# ..   ...                    ...                  ...
# 66  2016  Golden State Warriors  Cleveland Cavaliers
# 67  2017  Golden State Warriors  Cleveland Cavaliers
# 68  2018  Golden State Warriors  Cleveland Cavaliers
# 69  2019  Golden State Warriors      Toronto Raptors
# 70  2020     Los Angeles Lakers           Miami Heat
#
# [71 rows x 3 columns]

# %%
champions_by_year.to_csv("csv_files/champions_by_year.csv", index=False)
runner_up_by_year.to_csv("csv_files/runner_up_by_year.csv", index=False)
mvp_by_year.to_csv("csv_files/mvp_by_year.csv", index=False)
finals_appearance.to_csv("csv_files/finals_appearance.csv", index=False)
